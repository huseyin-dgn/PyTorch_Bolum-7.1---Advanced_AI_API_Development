# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
import pickle

# %%
df = pd.read_csv(r"C:\Users\hdgn5\OneDrive\Masaüstü\Kendi API'mız\- Kendi API'mizi Kullanalım -\Sklearn - ML -\Dataset\dataset_regresyon.csv")  # senin verdiğin dosya ismi

X = df[["metrekare", "oda_sayisi", "bina_yasi"]]
y = df["fiyat"]

model = LinearRegression()
model.fit(X, y)

with open("model.pkl", "wb") as f:
    pickle.dump(model, f)

print("✅ Model başarıyla eğitildi ve kaydedildi → model.pkl")
# Out:
# ✅ Model başarıyla eğitildi ve kaydedildi → model.pkl
